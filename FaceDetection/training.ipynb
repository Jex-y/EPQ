# %%
import yolo

# %%
dataset = yolo.Dataset("data/dataset.yml", "train", image_size=416, augment=True)
val_dataset = yolo.Dataset("data/dataset.yml", "test", image_size=416, augment=False)

# %%
model = yolo.models.YOLOv4(num_classes=1)

# %%
model.fit(dataset, val_dataset=val_dataset,  first_stage_epochs=30, second_stage_epochs=20, start_lr = 1e-5, end_lr = 1e-6)
# Out:
# Epoch 1/50
# [0215|0328] [===================>            ] [00:01:10] - total loss: 54.46 - giou loss: 18.90 - conf loss: 35.28 - prob loss 0.28 - lr 0.000151
# [0081|0081] [================================] [00:00:12] - val total loss: 84.10 - val giou loss: 44.92 - val conf loss: 38.63 - val prob loss 0.56
# Checkpoint saved to epoch0001of0050.ckpt
# Epoch 2/50
# [0328|0328] [================================] [00:01:21] - total loss: 83.62 - giou loss: 61.76 - conf loss: 21.64 - prob loss 0.22 - lr 0.000151
# [0081|0081] [================================] [00:00:08] - val total loss: 39.53 - val giou loss: 22.99 - val conf loss: 16.51 - val prob loss 0.04
# Checkpoint saved to epoch0002of0050.ckpt
# Epoch 3/50
# [0328|0328] [================================] [00:01:21] - total loss: 98.74 - giou loss: 74.28 - conf loss: 24.28 - prob loss 0.17 - lr 0.000151
# ...

# %% [markdown]
# This is a demo of Yolo v4 using pretrained weights.

# %%
# Convert darknet weights to tensorflow 
# %cd tensorflow-yolov4-tflite
# !python save_model.py --weights ./data/yolov4.weights --output ./checkpoints/yolov4-416 --input_size 416 --model yolov4
# Out:
# [WinError 2] The system cannot find the file specified: 'tensorflow-yolov4-tflite'
# e:\EPQ\FaceDetection\tensorflow-yolov4-tflite
# 2020-07-31 12:40:30.465385: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cudart64_101.dll
# 2020-07-31 12:40:32.675461: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library nvcuda.dll
# 2020-07-31 12:40:32.697231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 980 computeCapability: 5.2
# coreClock: 1.2155GHz coreCount: 16 deviceMemorySize: 4.00GiB deviceMemoryBandwidth: 208.91GiB/s
# 2020-07-31 12:40:32.697661: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cudart64_101.dll
# 2020-07-31 12:40:32.701837: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cublas64_10.dll
# 2020-07-31 12:40:32.705695: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cufft64_10.dll
# 2020-07-31 12:40:32.707239: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library curand64_10.dll
# 2020-07-31 12:40:32.711581: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cusolver64_10.dll
# 2020-07-31 12:40:32.714396: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cusparse64_10.dll
# 2020-07-31 12:40:32.722514: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cudnn64_7.dll
# 2020-07-31 12:40:32.722802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-07-31 12:40:32.723438: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-07-31 12:40:32.731425: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x216453dcab0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-31 12:40:32.731799: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-31 12:40:32.732227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 980 computeCapability: 5.2
# coreClock: 1.2155GHz coreCount: 16 deviceMemorySize: 4.00GiB deviceMemoryBandwidth: 208.91GiB/s
# 2020-07-31 12:40:32.732718: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cudart64_101.dll
# 2020-07-31 12:40:32.732954: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cublas64_10.dll
# 2020-07-31 12:40:32.733181: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cufft64_10.dll
# 2020-07-31 12:40:32.733400: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library curand64_10.dll
# 2020-07-31 12:40:32.733703: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cusolver64_10.dll
# 2020-07-31 12:40:32.733937: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cusparse64_10.dll
# 2020-07-31 12:40:32.734172: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library cudnn64_7.dll
# 2020-07-31 12:40:32.734426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-07-31 12:40:33.292417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-07-31 12:40:33.292656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-07-31 12:40:33.292790: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-07-31 12:40:33.293092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 2982 MB memory) -> physical GPU (device: 0, name: GeForce GTX 980, pci bus id: 0000:01:00.0, compute capability: 5.2)
# 2020-07-31 12:40:33.296594: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2167964f2a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-07-31 12:40:33.296921: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce GTX 980, Compute Capability 5.2
# Traceback (most recent call last):
#   File "save_model.py", line 58, in <module>
#     app.run(main)
#   File "C:\Users\markj\.conda\envs\epq\lib\site-packages\absl\app.py", line 299, in run
#     _run_main(main, args)
#   File "C:\Users\markj\.conda\envs\epq\lib\site-packages\absl\app.py", line 250, in _run_main
#     sys.exit(main(argv))
#   File "save_model.py", line 54, in main
#     save_tf()
#   File "save_model.py", line 49, in save_tf
#     utils.load_weights(model, FLAGS.weights, FLAGS.model, FLAGS.tiny)
#   File "e:\EPQ\FaceDetection\tensorflow-yolov4-tflite\core\utils.py", line 36, in load_weights
#     wf = open(weights_file, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: './data/yolov4.weights'

# %%
# Run detections on sample image
# !python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --image ./data/kite.jpg

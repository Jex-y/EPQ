# %%
import tensorflow as tf
import yolo
import json
import os
import cv2
import numpy as np

# %%
DATASET_DIR = "data"
model = yolo.models.YOLOv4(1)

img = cv2.imread(os.path.join(DATASET_DIR, "0b1ec34d743faf93b7db125734a1f0056d987e960f79981f0a3ab279112732fb.jpg"))

model(np.expand_dims(img,0).astype(np.float32)/255)
# Out:
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-2-805189925323> in <module>
#       4 img = cv2.imread(os.path.join(DATASET_DIR, "0b1ec34d743faf93b7db125734a1f0056d987e960f79981f0a3ab279112732fb.jpg"))
#       5
# ----> 6 model(np.expand_dims(img,0).astype(np.float32)/255)
#
# ~\.conda\envs\epq\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# e:\EPQ\FaceDetection\yolo\models.py in call(self, x)
#      83
#      84     def call(self, x):
# ---> 85         route_1, route_2, x = self.darknet(x)
#      86
#      87         route = x
#
# ...

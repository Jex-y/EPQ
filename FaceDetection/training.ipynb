# %%
import yolo

# %%
dataset = yolo.Dataset("data/dataset.yml", "train", image_size=416, augment=True)
val_dataset = yolo.Dataset("data/dataset.yml", "test", image_size=416, augment=False)

# %%
model = yolo.models.YOLOv4(num_classes=1)

# %%
model.fit(dataset, val_dataset=val_dataset,  first_stage_epochs=30, second_stage_epochs=20, start_lr = 1e-4, end_lr = 1e-7)
# Out:
# Epoch 1/50
# [0328|0328] [================================] [00:01:47] - total loss: 312.41 - giou loss: 63.35 - conf loss: 248.10 - prob loss 0.96 - lr 0.000307
# [0081|0081] [================================] [00:00:10] - val total loss: 46.66 - val giou loss: 13.17 - val conf loss: 33.41 - val prob loss 0.08
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# ~\.conda\envs\epq\lib\site-packages\tensorflow\python\ops\gen_io_ops.py in save_v2(prefix, tensor_names, shape_and_slices, tensors, name)
#    1699     try:
# -> 1700       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1701         _ctx._context_handle, tld.device_name, "SaveV2", name,
#
# _FallbackException: This function does not handle the case of the path where all inputs are not already EagerTensors.
#
# During handling of the above exception, another exception occurred:
#
# ...

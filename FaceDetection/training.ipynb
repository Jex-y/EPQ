# %%
import tensorflow as tf
import yolo
import json
import os
import cv2
import numpy as np

# %%
# Idk what this bit does but it makes it work for some reason. 
# Ok I think that it limits the amount of memory that it can use. I should probably run this on a card with more memory but that is expensive. 
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
model = yolo.models.YOLOv4(num_classes=1)
raw_dataset = tf.data.TFRecordDataset("data/train.tfrecord")
raw_dataset = raw_dataset.map(model.get_dataset_parse_func())

# %%
raw_dataset.map(model.get_dataset_preprocess_func())
# Out:
# preprocess called
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-8757873327a0> in <module>
# ----> 1 raw_dataset.map(model.get_dataset_preprocess_func())
#
# ~\.conda\envs\epq\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1619     """
#    1620     if num_parallel_calls is None:
# -> 1621       return MapDataset(self, map_func, preserve_cardinality=True)
#    1622     else:
#    1623       return ParallelMapDataset(
#
# ~\.conda\envs\epq\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    3975     self._use_inter_op_parallelism = use_inter_op_parallelism
#    3976     self._preserve_cardinality = preserve_cardinality
# ...
